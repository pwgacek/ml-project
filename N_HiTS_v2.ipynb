# %%
# UNCOMMENT AND RUN IF ON COLAB
# %env PYTHONPATH = # /env/python
# !wget https://repo.anaconda.com/miniconda/Miniconda3-py38_4.12.0-Linux-x86_64.sh
# !chmod +x Miniconda3-py38_4.12.0-Linux-x86_64.sh
# !./Miniconda3-py38_4.12.0-Linux-x86_64.sh -b -f -p /usr/local
# !conda update conda

import sys
sys.path.append('/usr/local/lib/python3.8/site-packages')
# Out:
# env: PYTHONPATH=# /env/python
# --2026-01-01 17:06:34--  https://repo.anaconda.com/miniconda/Miniconda3-py38_4.12.0-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.32.241, 104.16.191.158, 2606:4700::6810:bf9e, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.32.241|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 76120962 (73M) [application/x-sh]
# Saving to: ‘Miniconda3-py38_4.12.0-Linux-x86_64.sh’
#
# Miniconda3-py38_4.1 100%[===================>]  72.59M   133MB/s    in 0.5s
#
# 2026-01-01 17:06:34 (133 MB/s) - ‘Miniconda3-py38_4.12.0-Linux-x86_64.sh’ saved [76120962/76120962]
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - _openmp_mutex==4.5=1_gnu
#     - brotlipy==0.7.0=py38h27cfd23_1003
#     - ca-certificates==2022.3.29=h06a4308_1
# ...

# %%
# !apt-get update  -y --fix-missing && \
    apt-get install -y --no-install-recommends \
    software-properties-common \
    wget \
    curl \
    unrar \
    unzip \
    git && \
    apt-get upgrade -y libstdc++6 && \
    apt-get clean -y
# !add-apt-repository ppa:ubuntu-toolchain-r/test && \
    apt-get update && \
    apt-get install -y gcc-9 && \
    apt-get upgrade -y libstdc++6
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:4 https://cli.github.com/packages stable/main amd64 Packages [345 B]
# Get:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,225 kB]
# Get:6 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:7 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:12 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# ...

# %%
# !git clone https://github.com/pwgacek/n-hits.git
import os
os.chdir("/content/n-hits")
# Out:
# Cloning into 'n-hits'...
# remote: Enumerating objects: 252, done.
# remote: Counting objects: 100% (137/137), done.
# remote: Compressing objects: 100% (80/80), done.
# remote: Total 252 (delta 77), reused 107 (delta 57), pack-reused 115 (from 1)
# Receiving objects: 100% (252/252), 5.77 MiB | 18.34 MiB/s, done.
# Resolving deltas: 100% (107/107), done.

# %%
# !conda create -n hits-env python=3.7
# %pip install -r requirements.txt

# %%
from src.experiments.transform import transform

datasets = [
    '/content/n-hits/data/air-pollution.csv',
    '/content/n-hits/data/microsoft-stock.csv',
    '/content/n-hits/data/household_power_consumption_hourly_clean.csv',
    '/content/n-hits/data/QPS_clean.csv',
    '/content/n-hits/data/sales_clean.csv',
    '/content/n-hits/data/wind-power-generation.csv',
]

for path in datasets:
    transform(path)

# %%
# !bash nhits.sh
# Out:
# -------------------------------------------------- air-pollution --------------------------------------------------
# -------------------------------------------------- 96 --------------------------------------------------
# Y_df:                      ds  ...         y
# 0  2022-02-01 00:00:00  ... -1.344341
# 1  2022-02-01 00:00:00  ...  3.836549
# 2  2022-02-01 00:00:00  ...  2.939795
# 3  2022-02-01 00:00:00  ...  2.481743
# 4  2022-02-01 00:00:00  ... -1.265276
#
# [5 rows x 3 columns]
# Hyperparameter optimization
# ...
#
# activation                                          ReLU
# batch_normalization                                False
# batch_size                                             1
# complete_windows                                    True
# dropout_prob_exogenous                                 0
# dropout_prob_theta                                     0
# early_stop_patience                                   10
# ...

# %%
# !bash evaluate.sh
