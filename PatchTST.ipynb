# %%
# %env PYTHONPATH = /env/python
# !wget https://repo.anaconda.com/miniconda/Miniconda3-py311_25.11.1-1-Linux-x86_64.sh
# !chmod +x Miniconda3-py311_25.11.1-1-Linux-x86_64.sh
# !./Miniconda3-py311_25.11.1-1-Linux-x86_64.sh -b -f -p /usr/local
# !conda update conda


import sys
sys.path.append('/usr/local/lib/python3.11/site-packages')
# Out:
# env: PYTHONPATH=/env/python
# --2025-12-27 13:22:45--  https://repo.anaconda.com/miniconda/Miniconda3-py311_25.11.1-1-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.32.241, 104.16.191.158, 2606:4700::6810:bf9e, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.32.241|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 155144821 (148M) [application/octet-stream]
# Saving to: ‘Miniconda3-py311_25.11.1-1-Linux-x86_64.sh’
#
# Miniconda3-py311_25 100%[===================>] 147.96M   290MB/s    in 0.5s
#
# 2025-12-27 13:22:46 (290 MB/s) - ‘Miniconda3-py311_25.11.1-1-Linux-x86_64.sh’ saved [155144821/155144821]
#
# PREFIX=/usr/local
# Unpacking bootstrapper...
# Unpacking payload...
#
# Installing base environment...
#
# Preparing transaction: ...working... done
# Executing transaction: ...working... done
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
# ...

# %%
# !python --version
# Out:
# Python 3.11.14

# %%
# !git clone https://github.com/thuml/Time-Series-Library.git
# %cd Time-Series-Library

# !git checkout --detach f56ef6dc4f3b334d2555121058bea0e967ac822b # for reproducibility
# !pip install -r requirements.txt
# Out:
# Cloning into 'Time-Series-Library'...
# remote: Enumerating objects: 2202, done.
# remote: Total 2202 (delta 0), reused 0 (delta 0), pack-reused 2202 (from 1)
# Receiving objects: 100% (2202/2202), 78.37 MiB | 38.49 MiB/s, done.
# Resolving deltas: 100% (1511/1511), done.
# /content/Time-Series-Library
# HEAD is now at f56ef6d Update contact information in README.md
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 906.5/906.5 MB 28.4 MB/s  0:00:17
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.3/16.3 MB 151.3 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.9/35.9 MB 61.1 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 197.1 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 213.8 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 169.5 MB/s  0:00:00
# ...

# %%
import os
os.environ["MPLBACKEND"] = "notebook"

# %% [markdown]
# - Make scripts runnable on linux (when edited on windows):
# `sed -i 's/\r$//' /content/drive/MyDrive/um_proj/patch_tst_runner.sh`

# %%
# %cd Time-Series-Library
# !bash /content/drive/MyDrive/um_proj/patch_tst_runner.sh
# Out:
# [Errno 2] No such file or directory: 'Time-Series-Library'
# /content/Time-Series-Library
# Dataset: household_power (data: household_power_consumption_hourly_clean.csv, freq: h)
# Running with pred_len=96 (seq_len=96, label_len=48)
#  See https://github.com/google-research/timesfm/blob/master/README.md for updated APIs.
# Loaded PyTorch TimesFM, likely because python version is 3.11.14 (main, Oct 21 2025, 18:31:21) [GCC 11.2.0].
# Using GPU
# Args in experiment:
# Basic Config
#   Task Name:          long_term_forecast  Is Training:        1
#   Model ID:           household_power_96_96Model:              PatchTST
#
# Data Loader
#   Data:               custom              Root Path:          /content/drive/MyDrive/um_proj/datasets
#   Data Path:          household_power_consumption_hourly_clean.csvFeatures:           M
#   Target:             Voltage             Freq:               h
#   Checkpoints:        ./checkpoints/
#
# Forecasting Task
# ...
